# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from IPython.display import display
import webbrowser
import matplotlib.cm as cm
import matplotlib.colors as colors
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
from IPython.display import Image # libraries for displaying images
from IPython.core.display import HTML
from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library
import folium  # plotting library
import json # library to handle JSON files
from sklearn.cluster import KMeans

# %%
# Porto foursquare data (Restaurants) using
CLIENT_ID = 'UVTNILL2IV4154IMVZ4IKSM3DQMSUWA1ZH5XJHWGBPEI0SQO'
CLIENT_SECRET = 'DGIKUTMF4DNVXHQ1DE1YYYFVAB4LUCAIT4VQV1I2BPL35KPE'
ACCESS_TOKEN = 'HNKCWZPBPCR1UJOYQSPVJHRBE2BGY5OZ0IFUAQNMAXB1YDEB'
VERSION = '20180606'
porto_latitude = '41.17010980423212'
porto_longitude = '-8.613142709814989'
search_query ='Restaurant'
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 5000 # define radius

#get the Porto restaurants
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, CLIENT_SECRET, porto_latitude, porto_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

porto = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(porto)
dataframe.head()

Porto_restaurants_filtered = dataframe.drop(['referralId','hasPerk','location.labeledLatLngs','location.distance','location.city','location.country',
                                              'location.state','location.cc','location.formattedAddress','location.address',
                                              'location.postalCode','location.crossStreet'],axis=1)
pd.set_option('display.max_columns',5)
pd.set_option("max_colwidth", 150)

p_latitude = 41.17010980423212
p_longitude = -8.613142709814989
# create map of Porto using latitude and longitude values
Porto_restaurants_map = folium.Map(location=[p_latitude, p_longitude], zoom_start=10)
# add markers to map
for lat, lng, restaurant_name in zip(Porto_restaurants_filtered['location.lat'], Porto_restaurants_filtered['location.lng'],
                                           Porto_restaurants_filtered['name']):
    label = '{}'.format(restaurant_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Porto_restaurants_map)

Porto_restaurants_map
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ...

# %%
# Porto foursquare data (Hostels) using
CLIENT_ID = 'UVTNILL2IV4154IMVZ4IKSM3DQMSUWA1ZH5XJHWGBPEI0SQO'
CLIENT_SECRET = 'DGIKUTMF4DNVXHQ1DE1YYYFVAB4LUCAIT4VQV1I2BPL35KPE'
ACCESS_TOKEN = 'HNKCWZPBPCR1UJOYQSPVJHRBE2BGY5OZ0IFUAQNMAXB1YDEB'
VERSION = '20180606'
porto_latitude = '41.17010980423212'
porto_longitude = '-8.613142709814989'
search_query ='Hostel'
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 5000 # define radius

#get the Porto hostels
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, CLIENT_SECRET, porto_latitude, porto_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

hostel = results['response']['venues']
# tranform venues into a dataframe
porto_hostel = json_normalize(hostel)
porto_hostel.head()

Porto_hostel_filtered = porto_hostel.drop(['referralId','hasPerk','location.labeledLatLngs','location.distance','location.city','location.country',
                                              'location.state','location.cc','location.formattedAddress','location.address',
                                              'location.postalCode','location.crossStreet','venuePage.id'],axis=1)
pd.set_option('display.max_columns',5)
pd.set_option("max_colwidth", 150)

p_latitude = 41.17010980423212
p_longitude = -8.613142709814989
# create map of Porto using latitude and longitude values
Porto_hostels_map = folium.Map(location=[p_latitude, p_longitude], zoom_start=10)
# add markers to map
for lat, lng, hostel_name in zip(Porto_hostel_filtered['location.lat'], Porto_hostel_filtered['location.lng'],
                                           Porto_hostel_filtered['name']):
    label = '{}'.format(hostel_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=1,
        parse_html=False).add_to(Porto_hostels_map)

Porto_hostels_map
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ...

# %%
#Porto foursquare data (Bars) using

CLIENT_ID = 'UVTNILL2IV4154IMVZ4IKSM3DQMSUWA1ZH5XJHWGBPEI0SQO'
CLIENT_SECRET = 'DGIKUTMF4DNVXHQ1DE1YYYFVAB4LUCAIT4VQV1I2BPL35KPE'
ACCESS_TOKEN = 'HNKCWZPBPCR1UJOYQSPVJHRBE2BGY5OZ0IFUAQNMAXB1YDEB'
VERSION = '20180606'
porto_latitude = '41.17010980423212'
porto_longitude = '-8.613142709814989'
search_query ='Bar, Café, Cafe, coffee'
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 5000 # define radius

#get the Porto bars and cafes
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, CLIENT_SECRET, porto_latitude, porto_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

barcafe = results['response']['venues']
# tranform venues into a dataframe
porto_barcafe = json_normalize(barcafe)
porto_barcafe.head()
porto_barcafe = porto_barcafe.sort_values('name')
#porto_barcafe = porto_barcafe.drop([41,37,21,25,14,7,22,31,26,17,8,6,36,42,38])

Porto_barcafe_filtered = porto_barcafe.drop(['referralId','hasPerk','location.labeledLatLngs','location.distance','location.city','location.country',
                                              'location.state','location.cc','location.formattedAddress','location.address',
                                             'location.postalCode','location.crossStreet'],axis=1)

pd.set_option('display.max_columns',5)
pd.set_option("max_colwidth", 150)

p_latitude = 41.17010980423212
p_longitude = -8.613142709814989
# create map of Porto using latitude and longitude values
Porto_barcafe_map = folium.Map(location=[p_latitude, p_longitude], zoom_start=10)
# add markers to map
for lat, lng, bar_cafe_name in zip(Porto_barcafe_filtered['location.lat'], Porto_barcafe_filtered['location.lng'],
                                           Porto_barcafe_filtered['name']):
    label = '{}'.format(bar_cafe_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Porto_barcafe_map)

Porto_barcafe_map
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:23: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ...

# %%
porto_barcafe = porto_barcafe.drop([41,35,21,28,15,6,26,18,34,8,12,31,38,42,36])

# %%
#Porto foursquare data (Bars) using

Porto_barcafe_filtered = porto_barcafe.drop(['referralId','hasPerk','location.labeledLatLngs','location.distance','location.city','location.country',
                                              'location.state','location.cc','location.formattedAddress','location.address',
                                             'location.postalCode','location.crossStreet'],axis=1)

pd.set_option('display.max_columns',5)
pd.set_option("max_colwidth", 150)

p_latitude = 41.17010980423212
p_longitude = -8.613142709814989
# create map of Porto using latitude and longitude values
Porto_barcafe_map = folium.Map(location=[p_latitude, p_longitude], zoom_start=10)
# add markers to map
for lat, lng, bar_cafe_name in zip(Porto_barcafe_filtered['location.lat'], Porto_barcafe_filtered['location.lng'],
                                           Porto_barcafe_filtered['name']):
    label = '{}'.format(bar_cafe_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Porto_barcafe_map)

Porto_barcafe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
#Hostels
Porto_map = folium.Map(location=[p_latitude, p_longitude], zoom_start=10)
# add markers to map
for lat, lng, hostel_name in zip(Porto_hostel_filtered['location.lat'], Porto_hostel_filtered['location.lng'],
                                           Porto_hostel_filtered['name']):
    label = '{}'.format(hostel_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=1,
        parse_html=False).add_to(Porto_map)

#restaurants
for lat, lng, restaurant_name in zip(Porto_restaurants_filtered['location.lat'], Porto_restaurants_filtered['location.lng'],
                                           Porto_restaurants_filtered['name']):
    label = '{}'.format(restaurant_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Porto_map)

#Bars and cafes
for lat, lng, bar_cafe_name in zip(Porto_barcafe_filtered['location.lat'], Porto_barcafe_filtered['location.lng'],
                                           Porto_barcafe_filtered['name']):
    label = '{}'.format(bar_cafe_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Porto_map)


Porto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
#Porto_barcafe_filtered = Porto_barcafe_filtered.drop(['location.neighborhood'],axis=1)
Porto_hostel_filtered
Porto_restaurants_filtered
Porto_bar_restaurants = pd.concat([Porto_restaurants_filtered, Porto_barcafe_filtered])
Porto_bar_restaurants = Porto_bar_restaurants.reset_index(drop=True)


p_latitude = 41.17010980423212
p_longitude = -8.613142709814989
#Lets try to apply K_means
PortoClustering = Porto_bar_restaurants.drop(['id','name','categories'],axis=1)
# set number of clusters
kclusters = 10
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(PortoClustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# add clustering labels
Porto_bar_restaurants.insert(0, 'Cluster Labels', kmeans.labels_)
Porto_Clustering_labels10 = Porto_bar_restaurants

# create map
map_porto_clusters = folium.Map(location=[p_latitude, p_longitude], zoom_start=11)
# set color scheme for the clusters
#x = np.arange(kclusters)
#ys = [i + x + (i * x) ** 2 for i in range(kclusters)]
#colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
#rainbow = [colors.rgb2hex(i) for i in colors_array]
#colorss = ['blue','green','red','purple','yellow']
colorss = ['blue','green','red','purple','yellow','aqua','orange','chocolate','saddlebrown','darkslategray']
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Porto_Clustering_labels10['location.lat'], Porto_Clustering_labels10['location.lng'],
                                  Porto_Clustering_labels10['name'], Porto_Clustering_labels10['Cluster Labels']):

    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=colorss[cluster - 1],
        fill=True,
        fill_color=colorss[cluster - 1],
        fill_opacity=1).add_to(map_porto_clusters)

for lat, lng, hostel_name in zip(Porto_hostel_filtered['location.lat'], Porto_hostel_filtered['location.lng'],
                                           Porto_hostel_filtered['name']):
    label = '{}'.format(hostel_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=1,
        parse_html=False).add_to(map_porto_clusters)

    folium.Circle([41.16642339978533, -8.612789594244271],radius=600,color='red',parse_html=False).add_to(map_porto_clusters)
    folium.Circle([41.16713414342439, -8.627380810920938],radius=600,color='aqua',parse_html=False).add_to(map_porto_clusters)
    folium.Circle([41.18018461061917, -8.605064832294241], radius=600, color='darkslategray', parse_html=False).add_to(map_porto_clusters)
    folium.Circle([41.15776463091605, -8.64549108597946], radius=600, color='orange', parse_html=False).add_to(map_porto_clusters)

map_porto_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...
